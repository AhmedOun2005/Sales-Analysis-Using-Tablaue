# %%
import pandas as pd
data=pd.read_excel(r"Data_before_cleaning.xlsx")
data=data.sort_values(by='ORDERNUMBER')
data
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 1267        10100               22      86.51                4  1903.22
# 578         10100               30     100.00                3  5151.00
# 680         10100               50      67.80                2  3390.00
# 2024        10100               49      34.47                1  1689.03
# 728         10101               25     100.00                4  3782.00
# ...           ...              ...        ...              ...      ...
# 1341        10425               38     100.00               13  4325.16
# 2405        10425               18     100.00                2  1895.94
# 1465        10425               55      46.82                1  2575.10
# 679         10425               28     100.00                3  5318.04
# 727         10425               38      99.41                7  3777.58
#
#       ORDERDATE      STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
def strf(s):
    g=''
    for i in s:
        if  i.isdigit():
            g+=i
    return g
data['PHONE']=data['PHONE'].apply(lambda x : strf(str(x)))
data
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 1267        10100               22      86.51                4  1903.22
# 578         10100               30     100.00                3  5151.00
# 680         10100               50      67.80                2  3390.00
# 2024        10100               49      34.47                1  1689.03
# 728         10101               25     100.00                4  3782.00
# ...           ...              ...        ...              ...      ...
# 1341        10425               38     100.00               13  4325.16
# 2405        10425               18     100.00                2  1895.94
# 1465        10425               55      46.82                1  2575.10
# 679         10425               28     100.00                3  5318.04
# 727         10425               38      99.41                7  3777.58
#
#       ORDERDATE      STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
# nullvalues =data['ADDRESSLINE2'].isnull().count()-data['ADDRESSLINE2'].count()# 2521
# ad2=data['ADDRESSLINE2'].drop_duplicates().count()# only have 9 address2
#drop address2
# data.drop('ADDRESSLINE2')
# data.drop('ADDRESSLINE2',axis='columns')
data #after remove address2
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 1267        10100               22      86.51                4  1903.22
# 578         10100               30     100.00                3  5151.00
# 680         10100               50      67.80                2  3390.00
# 2024        10100               49      34.47                1  1689.03
# 728         10101               25     100.00                4  3782.00
# ...           ...              ...        ...              ...      ...
# 1341        10425               38     100.00               13  4325.16
# 2405        10425               18     100.00                2  1895.94
# 1465        10425               55      46.82                1  2575.10
# 679         10425               28     100.00                3  5318.04
# 727         10425               38      99.41                7  3777.58
#
#       ORDERDATE      STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %% [markdown]
# Make a Column of State and Remove it from Data

# %%
print(data['STATE'].isnull().count())
print(data['STATE'].count())# null values
print(data['STATE'].drop_duplicates())
# Out:
# 2823
# 1337
# 1267               NH
# 728               NaN
# 501                NY
# 448                PA
# 476                CA
# 805          Victoria
# 1394               NV
# 937                MA
# 2745               CT
# 2075              NSW
# 2254       Queensland
# 453            Quebec
# 2623               BC
# 1573            Osaka
# 1076    Isle of Wight
# 2468               NJ
# 225             Tokyo
# Name: STATE, dtype: object

# %%
new_column_of_State = data[['ORDERNUMBER','STATE']].drop_duplicates()
column_State_count=data['STATE'].value_counts()
column_State_count
data=data.drop('STATE',axis='columns') #it is removed

# %%
data
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 1267        10100               22      86.51                4  1903.22
# 578         10100               30     100.00                3  5151.00
# 680         10100               50      67.80                2  3390.00
# 2024        10100               49      34.47                1  1689.03
# 728         10101               25     100.00                4  3782.00
# ...           ...              ...        ...              ...      ...
# 1341        10425               38     100.00               13  4325.16
# 2405        10425               18     100.00                2  1895.94
# 1465        10425               55      46.82                1  2575.10
# 679         10425               28     100.00                3  5318.04
# 727         10425               38      99.41                7  3777.58
#
#       ORDERDATE      STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...         PHONE  \
# ...

# %% [markdown]
# Make a Column of TERRITORY and Remove it from Data

# %%
print(data['TERRITORY'].isnull().count())
print(data['TERRITORY'].count())# null values
print(data['TERRITORY'].drop_duplicates())
# Out:
# 2823
# 1749
# 1267      NaN
# 728      EMEA
# 2432    Japan
# 805      APAC
# Name: TERRITORY, dtype: object

# %%
new_column_of_TERRITORY= data[['ORDERNUMBER','TERRITORY']].drop_duplicates()
column_TERRITORY_count=data['TERRITORY'].value_counts()
column_TERRITORY_count
data=data.drop('TERRITORY',axis='columns')

# %%
data
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 1267        10100               22      86.51                4  1903.22
# 578         10100               30     100.00                3  5151.00
# 680         10100               50      67.80                2  3390.00
# 2024        10100               49      34.47                1  1689.03
# 728         10101               25     100.00                4  3782.00
# ...           ...              ...        ...              ...      ...
# 1341        10425               38     100.00               13  4325.16
# 2405        10425               18     100.00                2  1895.94
# 1465        10425               55      46.82                1  2575.10
# 679         10425               28     100.00                3  5318.04
# 727         10425               38      99.41                7  3777.58
#
#       ORDERDATE      STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
data.isnull().count()-data.count() #POSTALCODE  is 76
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# POSTALCODE            76
# COUNTRY                0
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
data['POSTALCODE']=data['POSTALCODE'].fillna('UnKnow')

# %%
data
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 1267        10100               22      86.51                4  1903.22
# 578         10100               30     100.00                3  5151.00
# 680         10100               50      67.80                2  3390.00
# 2024        10100               49      34.47                1  1689.03
# 728         10101               25     100.00                4  3782.00
# ...           ...              ...        ...              ...      ...
# 1341        10425               38     100.00               13  4325.16
# 2405        10425               18     100.00                2  1895.94
# 1465        10425               55      46.82                1  2575.10
# 679         10425               28     100.00                3  5318.04
# 727         10425               38      99.41                7  3777.58
#
#       ORDERDATE      STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
data.isnull().count()-data.count() #no NULL
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# POSTALCODE             0
# COUNTRY                0
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
data
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 1267        10100               22      86.51                4  1903.22
# 578         10100               30     100.00                3  5151.00
# 680         10100               50      67.80                2  3390.00
# 2024        10100               49      34.47                1  1689.03
# 728         10101               25     100.00                4  3782.00
# ...           ...              ...        ...              ...      ...
# 1341        10425               38     100.00               13  4325.16
# 2405        10425               18     100.00                2  1895.94
# 1465        10425               55      46.82                1  2575.10
# 679         10425               28     100.00                3  5318.04
# 727         10425               38      99.41                7  3777.58
#
#       ORDERDATE      STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
data.to_excel("Data_After_Cleaning.xlsx",index=False)
